# %% [markdown]
# # DATOS DEL SENSOR DE OBSTACULO

# %%
import pandas as pd

# %% [markdown]
# # ACCESO A NUESTRA API

# %%
df = pd.read_json("http://localhost/bastonapi/Ctrdistancia/mostrar_distancia_obstaculo")

# %% [markdown]
# # VERIFICACION DE LOS DATOS DEL SENSOR DE OBSTACULO

# %%
df
# Out:
#     distancia      hora
# 0        87.9  15:21:49
# 1        87.9  15:22:04
# 2        78.7  23:35:58
# 3        89.9  23:35:58
# 4        66.8  23:36:24
# 5        54.9  23:36:24
# 6        66.8  23:37:24
# 7        54.9  23:37:24
# 8        54.9  23:37:24
# 9        94.5  23:37:24
# 10       94.9  23:37:24
# 11       67.8  23:37:53
# 12       65.8  23:37:53
# 13       67.8  23:39:10
# 14       65.8  23:39:10
# 15       47.8  23:39:10
# 16       65.8  23:39:10
# 17       67.8  23:39:10
# 18       65.8  23:39:10
# 19       67.8  23:39:10
# 20       75.8  23:39:10
# 21       69.8  23:39:10
# 22       65.8  23:39:10
# 23       37.8  23:39:10
# 24       65.8  23:39:10
# 25       87.8  23:39:10
# 26       95.8  23:39:10
# 27       67.8  23:39:10
# 28       34.8  23:39:10
# 29       67.8  23:39:10
# 30       65.8  23:39:10
# 31       47.4  23:39:43
# 32       51.7  23:39:43
# 33       80.1  23:40:53
# 34       79.4  23:40:53
# 35       80.1  23:41:14
# 36       79.4  23:41:14
# ...

# %% [markdown]
# # VERIFIACION DE INFORMACION DE API

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   distancia  49 non-null     float64
#  1   hora       49 non-null     object
# dtypes: float64(1), object(1)
# memory usage: 912.0+ bytes

# %% [markdown]
# # DATOS ESTADISTICOS DE NUESTRA API

# %%
df.describe()
# Out:
#        distancia
# count  49.000000
# mean   71.922449
# std    13.815907
# min    34.800000
# 25%    65.800000
# 50%    75.800000
# 75%    80.100000
# max    95.800000

# %%
relation = df[['distancia']]

# %%
relation.head()
# Out:
#    distancia
# 0       87.9
# 1       87.9
# 2       78.7
# 3       89.9
# 4       66.8

# %% [markdown]
# # GRAFICACION DE LOS DATOS "DISTANCIA"

# %%
import numpy as np

# %%
import seaborn as sns

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
sns.pairplot(relation, kind='reg')

# %%
sns.distplot(df.distancia)
# Out:
# /home/adolfo/my_project_dir/my_project_env/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='distancia', ylabel='Density'>

# %%
df = df.astype({"distancia":'float',
                })

# %%
df
# Out:
#     distancia      hora
# 0        87.9  15:21:49
# 1        87.9  15:22:04
# 2        78.7  23:35:58
# 3        89.9  23:35:58
# 4        66.8  23:36:24
# 5        54.9  23:36:24
# 6        66.8  23:37:24
# 7        54.9  23:37:24
# 8        54.9  23:37:24
# 9        94.5  23:37:24
# 10       94.9  23:37:24
# 11       67.8  23:37:53
# 12       65.8  23:37:53
# 13       67.8  23:39:10
# 14       65.8  23:39:10
# 15       47.8  23:39:10
# 16       65.8  23:39:10
# 17       67.8  23:39:10
# 18       65.8  23:39:10
# 19       67.8  23:39:10
# 20       75.8  23:39:10
# 21       69.8  23:39:10
# 22       65.8  23:39:10
# 23       37.8  23:39:10
# 24       65.8  23:39:10
# 25       87.8  23:39:10
# 26       95.8  23:39:10
# 27       67.8  23:39:10
# 28       34.8  23:39:10
# 29       67.8  23:39:10
# 30       65.8  23:39:10
# 31       47.4  23:39:43
# 32       51.7  23:39:43
# 33       80.1  23:40:53
# 34       79.4  23:40:53
# 35       80.1  23:41:14
# 36       79.4  23:41:14
# ...
