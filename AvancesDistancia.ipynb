# %% [markdown]
# # DATOS DE LOS SENSORES (BIG DATA)

# %%
import pandas as pd

# %% [markdown]
# # ACCESO A NUESTRA API

# %%
df = pd.read_json("http://localhost/bastonapi/Ctrdistancia/mostrar_distancia_ultrasonico")

# %% [markdown]
# # VERIFICACIÒN DE LOS DATOS DEL SENSOR DE DISTANCIA

# %%
df
# Out:
#     distancia      hora
# 0        78.9  15:20:43
# 1        78.9  15:20:50
# 2        45.0  15:44:23
# 3        24.0  15:44:27
# 4        43.0  15:44:34
# 5        43.0  15:44:40
# 6        51.0  15:44:47
# 7      2216.0  15:44:54
# 8       145.0  15:45:10
# 9        79.0  15:45:17
# 10       21.0  15:45:23
# 11       22.0  15:45:30
# 12     2215.0  15:45:37
# 13     2215.0  15:45:53
# 14      270.0  15:46:00
# 15     2215.0  15:46:07
# 16     2215.0  15:46:14
# 17     2215.0  15:46:31
# 18     2215.0  15:46:38
# 19      240.0  15:46:45
# 20     2215.0  15:47:01
# 21      253.0  15:47:08
# 22      551.0  15:47:14
# 23      236.0  15:47:31
# 24       25.0  15:47:38
# 25       72.0  15:47:58
# 26       39.0  15:48:05
# 27       30.0  15:48:12
# 28      253.0  15:48:23
# 29       25.0  15:48:31
# 30        0.0  16:07:14
# 31        0.0  16:07:22
# 32        0.0  16:07:40
# 33        0.0  16:07:59
# 34        0.0  16:08:06

# %% [markdown]
# # VERIFICACION DE INFORMACION TABLA API

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   distancia  35 non-null     float64
#  1   hora       35 non-null     object
# dtypes: float64(1), object(1)
# memory usage: 688.0+ bytes

# %% [markdown]
# # DATOS ESTADISTICOS DE NUESTRA API

# %%
df.describe()
# Out:
#          distancia
# count    35.000000
# mean    581.308571
# std     909.156922
# min       0.000000
# 25%      25.000000
# 50%      78.900000
# 75%     410.500000
# max    2216.000000

# %%
relation = df[['distancia']]

# %%
relation.head()
# Out:
#    distancia
# 0       78.9
# 1       78.9
# 2       45.0
# 3       24.0
# 4       43.0

# %% [markdown]
# # GRAFICACION DE LOS DATOS "DISTANCIA"

# %%
import numpy as np

# %%
import seaborn as sns

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
sns.pairplot(relation, kind='reg')

# %%
sns.distplot(df.distancia)
# Out:
# /home/adolfo/my_project_dir/my_project_env/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='distancia', ylabel='Density'>

# %%
df = df.astype({"distancia":'float',
                })

# %%
df
# Out:
#     distancia      hora
# 0        78.9  15:20:43
# 1        78.9  15:20:50
# 2        45.0  15:44:23
# 3        24.0  15:44:27
# 4        43.0  15:44:34
# 5        43.0  15:44:40
# 6        51.0  15:44:47
# 7      2216.0  15:44:54
# 8       145.0  15:45:10
# 9        79.0  15:45:17
# 10       21.0  15:45:23
# 11       22.0  15:45:30
# 12     2215.0  15:45:37
# 13     2215.0  15:45:53
# 14      270.0  15:46:00
# 15     2215.0  15:46:07
# 16     2215.0  15:46:14
# 17     2215.0  15:46:31
# 18     2215.0  15:46:38
# 19      240.0  15:46:45
# 20     2215.0  15:47:01
# 21      253.0  15:47:08
# 22      551.0  15:47:14
# 23      236.0  15:47:31
# 24       25.0  15:47:38
# 25       72.0  15:47:58
# 26       39.0  15:48:05
# 27       30.0  15:48:12
# 28      253.0  15:48:23
# 29       25.0  15:48:31
# 30        0.0  16:07:14
# 31        0.0  16:07:22
# 32        0.0  16:07:40
# 33        0.0  16:07:59
# 34        0.0  16:08:06
